# %%
# Importing Min Search and all libraries
import pandas as pd

# %%
df = pd.read_csv('../Data/Benchmarks(Final).csv')

# %%
df
# Out:
#      ids                                           question  \
# 0      0                          Can we hang out tomorrow?
# 1      1          Is there something you're not telling me?
# 2      2                          What did you dream about?
# 3      3                            Why don't you trust me?
# 4      5                                  How was your day?
# ..   ...                                                ...
# 760  761  What's your biggest fear about discussing our ...
# 761  762  What's your favorite thing about how we balanc...
# 762  763  How do you handle differences in our sleep hab...
# 763  764  Do you ever feel like you're not adventurous e...
# 764  765  How important is it to maintain a sense of pla...
#
#                                                 answer
# 0                I'd love that! Let's make some plans.
# 1    No, but sometimes I worry you might not trust me.
# 2                I dreamed about us, it was beautiful.
# ...

# %%
df = df.drop_duplicates(subset=['question'])

# %%
df.shape
# Out:
# (638, 3)

# %%
df
# Out:
#      ids                                           question  \
# 0      0                          Can we hang out tomorrow?
# 1      1          Is there something you're not telling me?
# 2      2                          What did you dream about?
# 3      3                            Why don't you trust me?
# 4      5                                  How was your day?
# ..   ...                                                ...
# 760  761  What's your biggest fear about discussing our ...
# 761  762  What's your favorite thing about how we balanc...
# 762  763  How do you handle differences in our sleep hab...
# 763  764  Do you ever feel like you're not adventurous e...
# 764  765  How important is it to maintain a sense of pla...
#
#                                                 answer
# 0                I'd love that! Let's make some plans.
# 1    No, but sometimes I worry you might not trust me.
# 2                I dreamed about us, it was beautiful.
# ...

# %%
df.to_csv("../Data/Final_data.csv",index=False)
